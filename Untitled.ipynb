# %%
print("Hello")
# Out:
# Hello

# %%
s="codegnan"
print(s[7:2])

# %%
print("hi")
# Out:
# hi

# %%
#slice s[start,end,step]
#start+step upto end-1
s="codegnan"
print(s[-1:-9:-1])
print(s[2:7])
print(s[-4:])
print(s[5:2])
print(s[3:100])
print(s[::-1])
print(s[-3::1])
print(s[-3:0:1])
print(s[10])
# Out:
# nangedoc
# degna
# gnan
#
# egnan
# nangedoc
# nan
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[22], line 12
#       8 print(s[3:100])
#       9 print(s[::-1])
#      10 print(s[-3::1])
#      11 print(s[-3:0:1])
# ---> 12 print(s[10])
#
# IndexError: string index out of range

# %%
s="codegnan"
print(s[-3::-1])
print(s[-3:-9:-1])
print(s[-3::1])
print(s[-3:0:1])
# Out:
# ngedoc
# ngedoc
# nan

# %%
s1=""
s2=str()
print(type(s1))
print(type(s2))
n=234
n1=234.543
print(type(n))
print(type(n1))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
s1='Z'
print(s[0]+s1+s[2:])
# Out:
# cZdegnan
